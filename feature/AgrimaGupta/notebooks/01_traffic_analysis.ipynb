# %% [markdown]
# # 01 — Traffic Analysis
#
# **FlashBalanceAI | Phase 2 — Dataset & Traffic Generation**
#
# **Purpose:** Explore and validate the synthetic flash-sale traffic generator and the Alibaba Cloud Cluster Trace dataset.
#
# **Covers (Issue #8 / Issue #10):**
# - Load and inspect Alibaba trace (`dataset/alibaba_cluster_trace/`)
# - Run `src/traffic/traffic_generator.py` for each scenario in `configs/traffic_config.yaml`
# - Plot arrival-rate time series for E1–E4, E6 scenarios
# - Verify burst multipliers (10×, 50×, 100×) and noise levels
# - Confirm episode length = 7 900 steps @ 100 ms resolution ≈ 13 min
# - Save representative plots to `experiments/results/traffic_profiles/`
#
# **Author:** Agrima Gupta (24BIT0253)
#
# > **NOTE — placeholder notebook.** Implementation begins in Phase 2 (Issue #8).

# %%
# TODO (Issue #8): install / import dependencies
# import numpy as np
# import matplotlib.pyplot as plt
# import yaml
# import sys; sys.path.insert(0, '..')
# from src.traffic.traffic_generator import TrafficGenerator

# %%
# TODO (Issue #8): load traffic_config.yaml
# with open('../configs/traffic_config.yaml') as f:
#     cfg = yaml.safe_load(f)
# print(cfg)

# %%
# TODO (Issue #8): generate and plot each traffic scenario
# for scenario_name, params in cfg['scenarios'].items():
#     gen = TrafficGenerator(**params)
#     series = gen.generate()
#     plt.plot(series, label=scenario_name)
# plt.xlabel('Step (100 ms)')
# plt.ylabel('Requests/s')
# plt.title('Flash-Sale Traffic Profiles')
# plt.legend()
# plt.savefig('../experiments/results/traffic_profiles/all_scenarios.png')
# plt.show()
