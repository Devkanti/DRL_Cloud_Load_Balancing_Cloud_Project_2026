# %% [markdown]
# # 02 — PPO Training
#
# **FlashBalanceAI | Phase 3 — DRL Implementation**
#
# **Purpose:** Train the PPO agent on `FlashSaleEnv` using hyperparameters from `configs/ppo_config.yaml`, monitor training curves, and save the best checkpoint.
#
# **Covers (Issue #11):**
# - Instantiate `FlashSaleEnv` with N=4 backends, 23-dim state, discrete action space
# - Load `ppo_config.yaml` hyperparameters
# - Train with `stable_baselines3.PPO` for 2 000 000 timesteps
# - Monitor reward curves via TensorBoard / inline matplotlib
# - Run `EvalCallback` on val seeds 112–126
# - Save best model to `models/ppo/best_model.zip`
# - Upload model to S3 (`models/ppo_flash_v1.zip`) for Phase 5 inference
#
# **Seed protocol (ADR-001 D18):**
# - Train seeds: 42–111
# - Val seeds: 112–126
# - Test seeds 127–141: **DO NOT USE HERE**
#
# **Author:** Agrima Gupta (24BIT0253)
#
# > **NOTE — placeholder notebook.** Implementation begins in Phase 3 (Issue #11).

# %%
# TODO (Issue #11): install / import dependencies
# import yaml
# import sys; sys.path.insert(0, '..')
# from stable_baselines3 import PPO
# from stable_baselines3.common.env_util import make_vec_env
# from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
# from src.environment.flash_sale_env import FlashSaleEnv

# %%
# TODO (Issue #11): load config
# with open('../configs/ppo_config.yaml') as f:
#     cfg = yaml.safe_load(f)
# print(cfg)

# %%
# TODO (Issue #11): create vectorised environment
# env = make_vec_env(FlashSaleEnv, n_envs=cfg['n_envs'], seed=cfg['seed_train'])

# %%
# TODO (Issue #11): instantiate and train PPO agent
# model = PPO(
#     'MlpPolicy', env,
#     learning_rate=cfg['learning_rate'],
#     n_steps=cfg['n_steps'],
#     batch_size=cfg['batch_size'],
#     n_epochs=cfg['n_epochs'],
#     gamma=cfg['gamma'],
#     gae_lambda=cfg['gae_lambda'],
#     clip_range=cfg['clip_range'],
#     ent_coef=cfg['ent_coef'],
#     vf_coef=cfg['vf_coef'],
#     policy_kwargs={'net_arch': cfg['net_arch']},
#     tensorboard_log=cfg['tensorboard_log'],
#     verbose=1,
# )
# model.learn(total_timesteps=cfg['total_timesteps'])
# model.save(cfg['save_dir'] + '/ppo_flash_v1')
